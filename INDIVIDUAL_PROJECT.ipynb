# %% [markdown]
# # INDIVIDUAL PROJECT
#
# In this final project, you will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice
#
# ------
# You will focus on bank stocks and see how they progressed throughout the [ financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to November 20th, 2023.

# %% [markdown]
# # Get The Data
# In this section, you will learn how to use pandas to directly read from Yahoo finance.
# First, you will need to install pandas_datareader (**pip install yfinance**), which will allow to to [read stock information directly from the internet](https://finance.yahoo.com/u/yahoo-finance/watchlists/bank-and-financial-services-stocks/)

# %% [markdown]
# # Import Library
# The Necesary Libraries have been imported for you already

# %%
# !pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (0.10.0)
# Requirement already satisfied: lxml in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from pandas-datareader) (4.9.2)
# Requirement already satisfied: pandas>=0.23 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from pandas-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas-datareader) (1.16.0)

# %%
# Import the Necessary Libraries
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %%
# You may need to install Yahoo Finance first
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (0.2.32)
# Requirement already satisfied: pandas>=1.3.0 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from yfinance) (2022.7)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from yfinance) (2.3.9)
# Requirement already satisfied: peewee>=3.16.2 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aliyahrouse/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2023.7.22)

# %% [markdown]
# # Data
# You need to get data using yahoo finance. You will get stock information for the following:
# * Bank Of America
# * Amazon
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Find the stock data from Jan 1st, 2006 to Novemebr 20 th 2023 for each of these banks.
#
# I. First, set each bank to be a separat dataframe, with the variable name for that bank being its ticker symbol. And then combine them using the concat method.
#
# II. Second, find the stock data altogether
#
# This will involve few steps

# %% [markdown]
# ### I. Setting the stock data for each bank separately and then combine
# * then as one single dataframe using pd.concat

# %%
# Step 1 import yfinance as yf
import yfinance as yf

# %%
# Step 2: Set the start and the end as follow:
start = "2006-01-01"
end = "2023-11-20"

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2023,11,20)

# %%
#Step 3:
#For the Signature Bank stock, you use yahoo finance (yf) and 
# the ticker name symbol "SBNY" for Signature Bank
SBNY = yf.download('SBNY', start, end)

# For the Silicon Valey Bank
SIVBQ = yf.download('SIVBQ', start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
AMZN = yf.download('AMZN', start, end)
BAC = yf.download('BAC', start, end)
JPM = yf.download('JPM', start, end)
C = yf.download('C', start, end)
GS = yf.download('GS', start, end)
MS = yf.download('MS', start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Step 4: set the tickers, using the stiker symbol for each Bank
tickers = ['SBNY','SIVBQ']

# %%
tickers = ['AMZN','BAC','JPM','C','GS','MS']

# %% [markdown]
# * Now, use pd.concat to concatenate the Banks DataFrames together
#     to a single data frame called stock_df

# %%
# Step 5: Use pandas to combine these two data as one dataframe
stock_df = pd.concat([SBNY,SIVBQ], axis=1, keys=tickers)

# %%
stock_df = pd.concat([AMZN,BAC,JPM,C,GS,MS], axis=1, keys=tickers)

# %%
# Setp 6: Check the first five row of these data
stock_df.head()
# Out:
#                  SBNY                                                      \
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2006-01-03  28.090000  28.620001  27.900000  28.500000  26.421671  377593
# 2006-01-04  28.450001  28.719999  28.290001  28.500000  26.421671  314188
# 2006-01-05  28.299999  28.500000  28.299999  28.400000  26.328962   48196
# 2006-01-06  28.650000  28.790001  28.150000  28.590000  26.505106   90469
# 2006-01-09  28.700001  28.820000  28.469999  28.799999  26.699793   87657
#
#                 SIVBQ
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 
# 2006-01-03  5377000
# 2006-01-04  7977800
# 2006-01-05  5778000
# 2006-01-06  6889800
# 2006-01-09  4144500

# %%
# You can plot individual stock. What can you say about 
# the Signature Bank?

SBNY['Open'].plot()
sns.despine()

# %%
import seaborn as sns

# %%
AMZN['Open'].plot()
sns.despine()

# %% [markdown]
#  # Task 1
#  * ## Mimic step 1 through step 6
#
#  to access the stock data of
#  * Amazon
# * Bank Of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
#
# from Jan 1st, 2006 to Novemebr 15th 2023 for each of these banks.
# Set each bank to be a separat dataframe, with the variable name for that bank being its ticker symbol. You find the ticker symbol for each Company. Use pandas to combine as a single dataframe, called stocks_df

# %%
# Amazon
AMZ = yf.download('AMZN', start, end)
# Bank of America
BAC = yf.download('BAC', start, end)
# JPMorgan Chase
JPM = yf.download('JPM',start, end)
# City Group
C = yf.download('C',start, end)
# Goldman Sachs
GS = yf.download('GS',start, end)
# Morgan Stanley
MS = yf.download('MS',start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
AMZN = yf.download('AMZN', start, end)
# Amazon
BAC = yf.download('BAC', start, end)
# Bank of America
JPM = yf.download('JPM',start, end)
# JP Morgan
C = yf.download('C',start, end)
# City Group
GS = yf.download('GS',start, end)
# Goldman Sachs 
MS = yf.download('MS',start, end)
# Morgan Stanley
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Create a list of tickers for thes stocks and call it tickers
tickers = [?????]

# %%
tickers = ['AMZN','BAC', 'C', 'GS', 'JPM', 'MS']

# %%
#use set_option to display all 36 columns of the stocks_df
pd.set_option('display.max_columns', 36)

# %%
pd.set_option('display.max_columns', 36)

# %%
stocks_df = pd.concat([AMZ ,BAC,C, GS,JPM,MS],axis=1,keys=tickers)
stocks_df.columns.names = ['Bank Ticker','Stock Info']

# %%
# Check the first five rows of the stocks_df
stocks_df.head(2)
# Out:
# Bank Ticker    AMZN                                                     BAC  \
# Stock Info     Open    High     Low   Close Adj Close     Volume       Open
# Date
# 2006-01-03   2.3735  2.3925  2.3125  2.3790    2.3790  151644000  46.919998
# 2006-01-04   2.3745  2.3865  2.3345  2.3625    2.3625  148818000  47.000000
#
# Bank Ticker                                                                 C  \
# Stock Info        High        Low      Close  Adj Close    Volume        Open
# Date
# 2006-01-03   47.180000  46.150002  47.080002  32.425461  16296700  490.000000
# 2006-01-04   47.240002  46.450001  46.580002  32.081085  17757900  488.600006
#
# Bank Ticker                                                           \
# Stock Info         High         Low       Close   Adj Close   Volume
# Date
# 2006-01-03   493.799988  481.100006  492.899994  338.403351  1537600
# 2006-01-04   491.000000  483.500000  483.799988  332.155579  1870960
#
# Bank Ticker          GS                                                 \
# Stock Info         Open        High         Low       Close  Adj Close
# Date
# 2006-01-03   126.699997  129.440002  124.230003  128.869995  98.890884
# 2006-01-04   127.349998  128.910004  126.379997  127.089996  97.525002
#
# Bank Ticker                 JPM                                              \
# Stock Info    Volume       Open       High        Low      Close  Adj Close
# Date
# 2006-01-03   6188700  39.830002  40.360001  39.299999  40.189999  24.948786
# 2006-01-04   4861600  39.779999  40.139999  39.419998  39.619999  24.804789
#
# Bank Ticker                   MS                                              \
# Stock Info     Volume       Open       High        Low      Close  Adj Close
# Date
# 2006-01-
# 2006-01-09   58.630001  178862000  15619400  1680740  4723500  16575200
#
# Bank Ticker
# Stock Info        MS
# Date
# 2006-01-03   5377000
# 2006-01-04   7977800
# 2006-01-05   5778000
# 2006-01-06   6889800
# 2006-01-09   4144500

# %% [markdown]
# # Task 2
#  * # EDA
# Let's explore the data a bit!

# %%
# What is the maximum Close Price for each Stock?
#(Hint use the stocks dataframe)
# Your code here
stocks["Close"].max()
# Out:
# Stock Info
# AMZN    186.570496
# BAC      54.900002
# C       564.099976
# GS      423.850006
# JPM     171.779999
# MS      108.730003
# dtype: float64

# %%
# Out:
# Stock Info
# AMZN    186.570496
# BAC      54.900002
# C       564.099976
# GS      423.850006
# JPM     171.779999
# MS      108.730003
# dtype: float64

# %% [markdown]
#  Create a new empty DataFrame called returns. This dataframe
# will contain the returns for each stock. Returns are obtained by
# $$r_t=\frac{p_t-p_{t-1}}{p_{t-1}}=\frac{p_t}{p_{t-1}}-1$$

# %%
returns = pd.DataFrame()

# %%
returns = pd.DataFrame()

# %% [markdown]
#  Use pandas pct_change() method on the Close column to create a column
#  representing this return value and store that result to the returns.

# %%
returns = stocks['Close'].pct_change()

# %%
returns = stocks['Close'].pct_change()

# %%
# Check the first five rows of the returns
returns.head()
# Out:
# Stock Info      AMZN       BAC         C        GS       JPM        MS
# Date
# 2006-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2006-01-04 -0.006936 -0.010620 -0.018462 -0.013812 -0.014183  0.000686
# 2006-01-05  0.008466  0.001288  0.004961 -0.000393  0.003029  0.002742
# 2006-01-06  0.004617 -0.001501  0.000000  0.014169  0.007046  0.001025
# 2006-01-09 -0.016503  0.000644 -0.004731  0.012030  0.016242  0.010586

# %%
returns.head()
# Out:
# Stock Info      AMZN       BAC         C        GS       JPM        MS  \
# Date
# 2006-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2006-01-04 -0.006936 -0.010620 -0.018462 -0.013812 -0.014183  0.000686
# 2006-01-05  0.008466  0.001288  0.004961 -0.000393  0.003029  0.002742
# 2006-01-06  0.004617 -0.001501  0.000000  0.014169  0.007046  0.001025
# 2006-01-09 -0.016503  0.000644 -0.004731  0.012030  0.016242  0.010586
#
# Stock Info       WFC
# Date
# 2006-01-03       NaN
# 2006-01-04 -0.011599
# 2006-01-05 -0.001110
# 2006-01-06  0.005874
# 2006-01-09 -0.000158

# %% [markdown]
# Using this returns DataFrame, figure out what dates each bank stock had the best and worst single day returns.You should notice that 3 of the banks have the same worst drop, did anything significant happen that day? Keep inmind that you are returning the index (date) and not the actual stock return value.

# %%
returns.idxmin()
# Out:
# Stock Info
# AMZN   2006-07-26
# BAC    2009-01-20
# C      2009-02-27
# GS     2009-01-20
# JPM    2009-01-20
# MS     2008-10-09
# dtype: datetime64[ns]

# %%
returns.idxmin()
# Out:
# Stock Info
# AMZN   2006-07-26
# BAC    2009-01-20
# C      2009-02-27
# GS     2009-01-20
# JPM    2009-01-20
# MS     2008-10-09
# WFC    2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# Stock Info
# AMZN   2007-04-25
# BAC    2009-04-09
# C      2008-11-24
# GS     2008-11-24
# JPM    2009-01-21
# MS     2008-10-13
# WFC    2008-07-16
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# Stock Info
# AMZN   2007-04-25
# BAC    2009-04-09
# C      2008-11-24
# GS     2008-11-24
# JPM    2009-01-21
# MS     2008-10-13
# dtype: datetime64[ns]

# %% [markdown]
# * # VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
# Graph the Close column for each stock in the stocks dataframe 
# that you've created. Is there any relationship between this plot 
# and the worst drop date of these stocks?
#your code here

# %%
AMZN['Close'].plot()
sns.despine()

# %%
BAC['Close'].plot()
sns.despine()

# %%
JPM['Close'].plot()
sns.despine()

# %%
C['Close'].plot()
sns.despine()

# %%
GS['Close'].plot()
sns.despine()

# %%
MS['Close'].plot()
sns.despine()

# %%
stocks['Close'].plot()
sns.despine()

# %%
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Why?

# %%
#Your code here

# %%
sns.pairplot(returns)

# %%
# Do histogram plot, for each of these stocks.
# Your code here

sns.histplot(data=stocks, x="AMZN", hue = 'origin')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 4
#       1 # Do histogram plot, for each of these stocks.
#       2 # Your code here
# ----> 4 sns.histplot(data=stocks, x="AMZN", hue = 'origin')
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/distributions.py:1395, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1374 def histplot(
#    1375     data=None, *,
#    1376     # Vector variables
#    (...)
#    1392     **kwargs,
#    1393 ):
# -> 1395     p = _DistributionPlotter(
#    1396         data=data,
#    1397         variables=_DistributionPlotter.get_semantics(locals())
#    1398     )
#    1400     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    1402     if ax is None:
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/distributions.py:113, in _DistributionPlotter.__init__(self, data, variables)
#     107 def __init__(
#     108     self,
#     109     data=None,
#     110     variables={},
#     111 ):
# --> 113     super().__init__(data=data, variables=variables)
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:640, in VectorPlotter.__init__(self, data, variables)
#     635 # var_ordered is relevant only for categorical axis variables, and may
#     636 # be better handled by an internal axis information object that tracks
#     637 # such information and is set up by the scale_* methods. The analogous
#     638 # information for numeric axes would be information about log scales.
#     639 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640 self.assign_variables(data, variables)
#     642 for var, cls in self._semantic_mappings.items():
#     643
#     644     # Create the mapping function
#     645     map_func = partial(cls.map, plotter=self)
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:701, in VectorPlotter.assign_variables(self, data, variables)
#     699 else:
#     700     self.input_format = "long"
# --> 701     plot_data, variables = self._assign_variables_longform(
#     702         data, **variables,
#     703     )
#     705 self.plot_data = plot_data
#     706 self.variables = variables
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:938, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     933 elif isinstance(val, (str, bytes)):
#     934
#     935     # This looks like a column name but we don't know what it means!
#     937     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938     raise ValueError(err)
#     940 else:
#     941
#     942     # Otherwise, assume the value is itself data
#     943
#     944     # Raise when data object is present and a vector can't matched
#     945     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `AMZN` for parameter `x`

# %% [markdown]
# # Moving Average

# %% [markdown]
# Plot the 30-day moving averages for JPM CHASE and Morgan Stanley stocks for the first 600 days. Use will need to use the individual daframe that you have create for each stock in Part I.

# %%
# Your code here

# %% [markdown]
# # Excellent Job!
